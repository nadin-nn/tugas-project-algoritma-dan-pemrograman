# %% [markdown]
# <a href="https://colab.research.google.com/github/nadin-nn/tugas-project-algoritma-dan-pemrograman/blob/main/project_alprog_sintaks_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
1*1
# Out:
# 1

# %%
3^2
# Out:
# 1
